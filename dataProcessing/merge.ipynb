# %%
import pandas as pd

# Read the CSV file
place_info_df = pd.read_csv('placeInfo.csv', index_col=0)

# Display the first few rows of the dataframe
place_info_df.head()
# Out:
#          start_hour   end_hour  average_duration  average_max_participants  \
# placeid
# 760       18.215743  18.623907          0.408163                  2.151603
# 761       15.892857  16.321429          0.428571                  3.107143
# 843       18.000000  18.430108          0.430108                  2.000000
# 854       16.425781  17.152344          0.726562                  3.253906
# 858       13.301242  13.987578          0.686335                  3.947205
#
#          amt  weight_avg               name   latitude  longitude
# placeid
# 760      364    2.194231  Carrefour Express  50.879021   4.703237
# 761       36    6.347222                NaN        NaN        NaN
# 843       98    0.753061  Carrefour Express  50.880237   4.697321
# 854      285    7.614035               Spar  50.880741   4.694760
# 858      375    9.423200    Delhaize Leuven  50.879549   4.698835

# %%
grades = pd.read_csv('placeGrades.csv', index_col=0)

# Display the first few rows of the dataframe
grades.head()
# Out:
#          grade
# placeid
# 760      0.900
# 761      0.400
# 843      0.300
# 854      0.200
# 858      0.234

# %%
place_info_df['grade'] = grades['grade']

# %%
place_info_df
# Out:
#          start_hour   end_hour  average_duration  average_max_participants  \
# placeid
# 760       18.215743  18.623907          0.408163                  2.151603
# 761       15.892857  16.321429          0.428571                  3.107143
# 843       18.000000  18.430108          0.430108                  2.000000
# 854       16.425781  17.152344          0.726562                  3.253906
# 858       13.301242  13.987578          0.686335                  3.947205
# 871       16.478261  16.478261          0.000000                  4.000000
# 876       15.329412  15.588235          0.258824                  3.541176
# 885       10.888889  11.888889          1.000000                  5.666667
# 950       15.428571  15.428571          0.000000                  2.000000
# 1178      17.111111  17.333333          0.222222                  2.888889
# 1417      17.200000  18.200000          1.000000                 11.700000
# ...

# %%
place_info_df.to_csv('placeOverall.csv')
